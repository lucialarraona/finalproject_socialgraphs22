# %%
# hello 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Understanding the dataset

# %%
# Read compressed csv with built-in gzip support
final3= pd.read_csv('../Data/final_datav3.csv', compression='gzip')
final3
# Out:
#                                               name      id  minutes  \
# 0       arriba   baked winter squash mexican style  137739       55
# 1                 a bit different  breakfast pizza   31490       30
# 2                               alouette  potatoes   59389       45
# 3                          apple a day  milk shake    5289        0
# 4                            aww  marinated olives   25274       15
# ...                                            ...     ...      ...
# 178260                          zydeco green beans  185979       20
# 178261                                zydeco salad  367912        5
# 178262                                zydeco sauce  357451       15
# 178263                          zydeco shrimp wrap  188810       57
# 178264                   zydeco ya ya deviled eggs  308080       40
#
#                                               ingredients  n_ingredients  \
# 0       ['winter squash', 'mexican seasoning', 'mixed ...              7
# ...

# %%
# Pickle a file and then compress it into a file with extension 
import bz2
import pickle
import _pickle as cPickle

# Load any compressed pickle file
def decompress_pickle(file):
 data = bz2.BZ2File(file, 'rb')
 data = cPickle.load(data)
 return data


data_reviews = decompress_pickle('../Data/reviews_zipped.pbz2') 
data_reviews.head()
# Out:
#    user_id  recipe_id        date  rating  \
# 0    38094      40893  2003-02-17       4
# 1  1293707      40893  2011-12-21       5
# 2     8937      44394  2002-12-01       4
# 3   126440      85009  2010-02-27       5
# 4    57222      85009  2011-10-01       5
#
#                                               review
# 0  Great with a salad. Cooked on top of stove for...
# 1  So simple, so delicious! Great for chilly fall...
# 2  This worked very well and is EASY.  I used not...
# 3  I made the Mexican topping and took it to bunk...
# 4  Made the cheddar bacon topping, adding a sprin...

# %%
print(f'The shape of our dataset {final3.shape}')
print(f'The shape of our dataset {data_reviews.shape}')
# Out:
# The shape of our dataset (178265, 6)
# The shape of our dataset (1132367, 5)
